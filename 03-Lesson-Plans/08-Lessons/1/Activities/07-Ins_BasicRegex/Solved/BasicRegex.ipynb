# %%
import pandas as pd
pd.options.display.max_colwidth = 100

# %%
# load in English words list
sherlock_file = '../Resources/sherlock.txt'

sherlock_df = pd.read_csv(sherlock_file, sep='\n', header=None)
sherlock_df.columns = ['text']
sherlock_df.head()
# Out:
#                                 text
# 0  The Adventures of Sherlock Holmes
# 1              by Arthur Conan Doyle
# 2                           Contents
# 3        I.     A Scandal in Bohemia
# 4       II.    The Red-Headed League

# %%
# find all lines of text with the string 'Watson'
p = 'Watson'
sherlock_df[sherlock_df['text'].str.contains(p)]
# Out:
#                                                    text
# 72    “Wedlock suits you,” he remarked. “I think, Wa...
# 76    fancy, Watson. And in practice again, I observ...
# 174   and fifty guineas apiece. There’s money in thi...
# 207   Watson, who is occasionally good enough to hel...
# 353   some good news for you. And good-night, Watson...
# ...                                                 ...
# 8795  “They always fill me with a certain horror. It...
# 9170  “My dear Watson, you as a medical man are cont...
# 9203  that we had better go in without you. Now, Wat...
# 9219  whose step I hear now upon the stair. I think,...
# 9297  the country surgeon and Mrs. Rucastle, so I th...
#
# [81 rows x 1 columns]

# %%
# find all lines of text with the string 'Watson' that are followed by a space
p = 'Watson\s'
sherlock_df[sherlock_df['text'].str.contains(p)]
# Out:
#                                                    text
# 869   your narrative. I ask you not merely because m...
# 1429           Watson and I will follow in the second.”
# 2981  jot down the facts. You will sign it, and Wats...
# 4949  came out into the frosty air. “Remember, Watso...

# %%
# find all lines of text with the string 'Watson' followed by a non-word character
p = 'Watson\W'
sherlock_df[sherlock_df['text'].str.contains(p)]
# Out:
#                                                    text
# 72    “Wedlock suits you,” he remarked. “I think, Wa...
# 76    fancy, Watson. And in practice again, I observ...
# 174   and fifty guineas apiece. There’s money in thi...
# 207   Watson, who is occasionally good enough to hel...
# 353   some good news for you. And good-night, Watson...
# ...                                                 ...
# 8795  “They always fill me with a certain horror. It...
# 9170  “My dear Watson, you as a medical man are cont...
# 9203  that we had better go in without you. Now, Wat...
# 9219  whose step I hear now upon the stair. I think,...
# 9297  the country surgeon and Mrs. Rucastle, so I th...
#
# [81 rows x 1 columns]
