# %% [markdown]
# # Plotting Query Results

# %% [markdown]
# ## Setup

# %%
# Import Matplot lib
import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
# Import SQLAlchemy `automap` and other dependencies here
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
# Create an engine for the `emoji.sqlite` database
engine = create_engine("sqlite:///../Resources/emoji.sqlite", echo=False)

# %% [markdown]
# ## Explore Database

# %%
# Use the Inspector to explore the database and print the table names
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['emoji']

# %%
# Use Inspector to print the column names and types
columns = inspector.get_columns('emoji')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# emoji_char TEXT
# emoji_id TEXT
# name TEXT
# score INTEGER

# %%
# Use `engine.execute` to select and display the first 10 rows from the emoji table
engine.execute('SELECT * FROM emoji LIMIT 10').fetchall()
# Out:
# [(1, '😂', '1F602', 'FACE WITH TEARS OF JOY', 1814832150),
#  (2, '❤️', '2764', 'HEAVY BLACK HEART', 840619939),
#  (3, '😍', '1F60D', 'SMILING FACE WITH HEART-SHAPED EYES', 680382416),
#  (4, '♥️', '2665', 'BLACK HEART SUIT', 652715459),
#  (5, '😭', '1F62D', 'LOUDLY CRYING FACE', 515991922),
#  (6, '😊', '1F60A', 'SMILING FACE WITH SMILING EYES', 484540701),
#  (7, '♻️', '267B', 'BLACK UNIVERSAL RECYCLING SYMBOL', 452489849),
#  (8, '😒', '1F612', 'UNAMUSED FACE', 441690175),
#  (9, '💕', '1F495', 'TWO HEARTS', 381679908),
#  (10, '😘', '1F618', 'FACE THROWING A KISS', 377847645)]

# %%
# Use `engine.execute` to select and display the first 10 rows from the emoji table
engine.execute('SELECT * FROM emoji').fetchall()
# Out:
# [(1, '😂', '1F602', 'FACE WITH TEARS OF JOY', 1814832150),
#  (2, '❤️', '2764', 'HEAVY BLACK HEART', 840619939),
#  (3, '😍', '1F60D', 'SMILING FACE WITH HEART-SHAPED EYES', 680382416),
#  (4, '♥️', '2665', 'BLACK HEART SUIT', 652715459),
#  (5, '😭', '1F62D', 'LOUDLY CRYING FACE', 515991922),
#  (6, '😊', '1F60A', 'SMILING FACE WITH SMILING EYES', 484540701),
#  (7, '♻️', '267B', 'BLACK UNIVERSAL RECYCLING SYMBOL', 452489849),
#  (8, '😒', '1F612', 'UNAMUSED FACE', 441690175),
#  (9, '💕', '1F495', 'TWO HEARTS', 381679908),
#  (10, '😘', '1F618', 'FACE THROWING A KISS', 377847645),
#  (11, '😩', '1F629', 'WEARY FACE', 343967555),
#  (12, '☺️', '263A', 'WHITE SMILING FACE', 333263710),
#  (13, '👌', '1F44C', 'OK HAND SIGN', 311468371),
#  (14, '😔', '1F614', 'PENSIVE FACE', 283873968),
#  (15, '😏', '1F60F', 'SMIRKING FACE', 275930731),
#  (16, '😁', '1F601', 'GRINNING FACE WITH SMILING EYES', 268504794),
#  (17, '⬅️', '2B05', 'LEFTWARDS BLACK ARROW', 225109999),
#  (18, '😉', '1F609', 'WINKING FACE', 210995480),
#  (19, '👍', '1F44D', 'THUMBS UP SIGN', 186214004),
#  (20, '😌', '1F60C', 'RELIEVED FACE', 180720579),
#  (21, '🙏', '1F64F', 'PERSON WITH FOLDED HANDS', 175057316),
#  (22, '🎶', '1F3B6', 'MULTIPLE MUSICAL NOTES', 170127733),
#  (23, '😢', '1F622', 'CRYING FACE', 166417040),
#  (24, '😎', '1F60E', 'SMILING FACE WITH SUNGLASSES', 160872106),
#  (25, '😅', '1F605', 'SMILING FACE WITH OPEN MOUTH AND COLD SWEAT', 160434523),
#  (26, '👀', '1F440', 'EYES', 159984970),
#  (27, '😳', '1F633', 'FLUSHED FACE', 156664610),
#  (28, '🙌', '1F64C', 'PERSON RAISING BOTH HANDS IN CELEBRATION', 154175844),
#  (29, '💔', '1F494', 'BROKEN HEART', 152572644),
#  (30, '🙈', '1F648', 'SEE-NO-EVIL MONKEY', 148162690),
#  (31, '✌️', '270C', 'VICTORY HAND', 143975239),
#  (32, '✨', '2728', 'SPARKLES', 139984564),
#  (33, '💙', '1F499', 'BLUE HEART', 139339131),
#  (34, '💜', '1F49C', 'PURPLE HEART', 137264417),
#  (35, '💯', '1F4AF', 'HUNDRED POINTS SYMBOL', 134780880),
#  (36, '😴', '1F634', 'SLEEPING FACE', 130865258),
#  (37, '😄', '1F604', 'SMILING FACE WITH OPEN MOUTH AND SMILING EYES', 130477038),
#  (38, '💖', '1F496', 'SPARKLING HEART', 130424962),
#  (39, '😑', '1F611', 'EXPRESSIONLESS FACE', 128234168),
#  (40, '😕', '1F615', 'CONFUSED FACE', 117379741),
#  (41, '😜', '1F61C', 'FACE WITH STUCK-OUT TONGUE AND WINKING EYE', 116339825),
#  (42, '😞', '1F61E', 'DISAPPOINTED FACE', 114838048),
#  (43, '😋', '1F60B', 'FACE SAVOURING DELICIOUS FOOD', 112633851),
#  (44, '😪', '1F62A', 'SLEEPY FACE', 108324223),
#  (45, '😐', '1F610', 'NEUTRAL FACE', 106264072),
#  (46, '👏', '1F44F', 'CLAPPING HANDS SIGN', 102799918),
#  (47, '💗', '1F497', 'GROWING HEART', 101184223),
#  (48, '🔥', '1F525', 'FIRE', 100755958),
#  (49, '💘', '1F498', 'HEART WITH ARROW', 100292305),
#  (50, '💁', '1F481', 'INFORMATION DESK PERSON', 100157815),
#  (51, '💞', '1F49E', 'REVOLVING HEARTS', 98235735),
#  (52, '👉', '1F449', 'WHITE RIGHT POINTING BACKHAND INDEX', 89030704),
#  (53, '📷', '1F4F7', 'CAMERA', 87426008),
#  (54, '💋', '1F48B', 'KISS MARK', 87163250),
#  (55, '🙊', '1F64A', 'SPEAK-NO-EVIL MONKEY', 86580161),
#  (56, '🌸', '1F338', 'CHERRY BLOSSOM', 85658369),
#  (57, '😱', '1F631', 'FACE SCREAMING IN FEAR', 85312719),
#  (58, '✋', '270B', 'RAISED HAND', 82829646),
#  (59, '😈', '1F608', 'SMILING FACE WITH HORNS', 79126643),
#  (60, '🌹', '1F339', 'ROSE', 78680533),
#  (61, '😡', '1F621', 'POUTING FACE', 77765674),
#  (62, '🎉', '1F389', 'PARTY POPPER', 74343725),
#  (63, '😃', '1F603', 'SMILING FACE WITH OPEN MOUTH', 73032826),
#  (64, '💀', '1F480', 'SKULL', 72768872),
#  (65, '💛', '1F49B', 'YELLOW HEART', 70983935),
#  (66, '😫', '1F62B', 'TIRED FACE', 70255616),
#  (67, '💪', '1F4AA', 'FLEXED BICEPS', 69816777),
#  (68, '▶️', '25B6', 'BLACK RIGHT-POINTING TRIANGLE', 69065216),
#  (69, '😝', '1F61D', 'FACE WITH STUCK-OUT TONGUE AND TIGHTLY-CLOSED EYES', 68397410),
#  (70, '👊', '1F44A', 'FISTED HAND SIGN', 67612477),
#  (71, '😆', '1F606', 'SMILING FACE WITH OPEN MOUTH AND TIGHTLY-CLOSED EYES', 67066945),
#  (72, '😀', '1F600', 'GRINNING FACE', 65760360),
#  (73, '🌚', '1F31A', 'NEW MOON WITH FACE', 65256066),
#  (74, '😤', '1F624', 'FACE WITH LOOK OF TRIUMPH', 63920738),
#  (75, '☀️', '2600', 'BLACK SUN WITH RAYS', 60958875),
#  (76, '😓', '1F613', 'FACE WITH COLD SWEAT', 59951054),
#  (77, '😻', '1F63B', 'SMILING CAT FACE WITH HEART-SHAPED EYES', 59648875),
#  (78, '💓', '1F493', 'BEATING HEART', 59562452),
#  (79, '✔️', '2714', 'HEAVY CHECK MARK', 59391321),
#  (80, '💚', '1F49A', 'GREEN HEART', 59228054),
#  (81, '😣', '1F623', 'PERSEVERING FACE', 56117603),
#  (82, '👈', '1F448', 'WHITE LEFT POINTING BACKHAND INDEX', 55226491),
#  (83, '😷', '1F637', 'FACE WITH MEDICAL MASK', 53880740),
#  (84, '➡️', '27A1', 'BLACK RIGHTWARDS ARROW', 52440798),
#  (85, '😇', '1F607', 'SMILING FACE WITH HALO', 52172894),
#  (86, '😛', '1F61B', 'FACE WITH STUCK-OUT TONGUE', 51288550),
#  (87, '👋', '1F44B', 'WAVING HAND SIGN', 50359440),
#  (88, '😚', '1F61A', 'KISSING FACE WITH CLOSED EYES', 50124691),
#  (89, '😥', '1F625', 'DISAPPOINTED BUT RELIEVED FACE', 50014772),
#  (90, '👑', '1F451', 'CROWN', 48711658),
#  (91, '✅', '2705', 'WHITE HEAVY CHECK MARK', 46436502),
#  (92, '😬', '1F62C', 'GRIMACING FACE', 46214249),
#  (93, '🎧', '1F3A7', 'HEADPHONE', 44572629),
#  (94, '😖', '1F616', 'CONFOUNDED FACE', 41026341),
#  (95, '😠', '1F620', 'ANGRY FACE', 40343477),
#  (96, '🌟', '1F31F', 'GLOWING STAR', 38590698),
#  (97, '🎵', '1F3B5', 'MUSICAL NOTE', 38146906),
#  (98, '😶', '1F636', 'FACE WITHOUT MOUTH', 37541092),
#  (99, '1️⃣', '0031-20E3', 'KEYCAP 1', 37313706),
#  (100, '🙋', '1F64B', 'HAPPY PERSON RAISING ONE HAND', 36950273),
#  (101, '👇', '1F447', 'WHITE DOWN POINTING BACKHAND INDEX', 36924974),
#  (102, '2️⃣', '0032-20E3', 'KEYCAP 2', 36389557),
#  (103, '👎', '1F44E', 'THUMBS DOWN SIGN', 35779058),
#  (104, '💃', '1F483', 'DANCER', 35537189),
#  (105, '🔫', '1F52B', 'PISTOL', 35127839),
#  (106, '🔴', '1F534', 'LARGE RED CIRCLE', 34949546),
#  (107, '💫', '1F4AB', 'DIZZY SYMBOL', 34331927),
#  (108, '↪️', '21AA', 'RIGHTWARDS ARROW WITH HOOK', 33725488),
#  (109, '💥', '1F4A5', 'COLLISION SYMBOL', 31687749),
#  (110, '👅', '1F445', 'TONGUE', 31561395),
#  (111, '↩️', '21A9', 'LEFTWARDS ARROW WITH HOOK', 31265883),
#  (112, '💭', '1F4AD', 'THOUGHT BALLOON', 30703227),
#  (113, '✊', '270A', 'RAISED FIST', 30436225),
#  (114, '©', '00A9', 'COPYRIGHT SIGN', 29288506),
#  (115, '✈️', '2708', 'AIRPLANE', 29088464),
#  (116, '💩', '1F4A9', 'PILE OF POO', 28739244),
#  (117, '😰', '1F630', 'FACE WITH OPEN MOUTH AND COLD SWEAT', 28662212),
#  (118, '😹', '1F639', 'CAT FACE WITH TEARS OF JOY', 28086059),
#  (119, '🙅', '1F645', 'FACE WITH NO GOOD GESTURE', 27772946),
#  (120, '◀️', '25C0', 'BLACK LEFT-POINTING TRIANGLE', 27520793),
#  (121, '🍃', '1F343', 'LEAF FLUTTERING IN WIND', 27297747),
#  (122, '🌞', '1F31E', 'SUN WITH FACE', 26637811),
#  (123, '💦', '1F4A6', 'SPLASHING SWEAT SYMBOL', 26459413),
#  (124, '🙆', '1F646', 'FACE WITH OK GESTURE', 26065980),
#  (125, '💎', '1F48E', 'GEM STONE', 26052152),
#  (126, '⚡️', '26A1', 'HIGH VOLTAGE SIGN', 25184506),
#  (127, '⭐️', '2B50', 'WHITE MEDIUM STAR', 25121321),
#  (128, '💤', '1F4A4', 'SLEEPING SYMBOL', 24579270),
#  (129, '🎈', '1F388', 'BALLOON', 24256440),
#  (130, '‼️', '203C', 'DOUBLE EXCLAMATION MARK', 24175977),
#  (131, '🍕', '1F355', 'SLICE OF PIZZA', 24148812),
#  (132, '👻', '1F47B', 'GHOST', 23687070),
#  (133, '🍀', '1F340', 'FOUR LEAF CLOVER', 23632134),
#  (134, '🎤', '1F3A4', 'MICROPHONE', 23447396),
#  (135, '⚽️', '26BD', 'SOCCER BALL', 23228233),
#  (136, '😟', '1F61F', 'WORRIED FACE', 22313732),
#  (137, '😨', '1F628', 'FEARFUL FACE', 22242378),
#  (138, '🚶', '1F6B6', 'PEDESTRIAN', 21909060),
#  (139, '🌺', '1F33A', 'HIBISCUS', 21875465),
#  (140, '🔞', '1F51E', 'NO ONE UNDER EIGHTEEN SYMBOL', 21530647),
#  (141, '🎀', '1F380', 'RIBBON', 21359361),
#  (142, '🐧', '1F427', 'PENGUIN', 21224279),
#  (143, '☑️', '2611', 'BALLOT BOX WITH CHECK', 20850012),
#  (144, '😙', '1F619', 'KISSING FACE WITH SMILING EYES', 20712464),
#  (145, '🌴', '1F334', 'PALM TREE', 20625064),
#  (146, '❌', '274C', 'CROSS MARK', 20027991),
#  (147, '👐', '1F450', 'OPEN HANDS SIGN', 19958716),
#  (148, '❄️', '2744', 'SNOWFLAKE', 19183977),
#  (149, '❗️', '2757', 'HEAVY EXCLAMATION MARK SYMBOL', 19106152),
#  (150, '👽', '1F47D', 'EXTRATERRESTRIAL ALIEN', 19071792),
#  (151, '💅', '1F485', 'NAIL POLISH', 18929340),
#  (152, '☝️', '261D', 'WHITE UP POINTING INDEX', 18772229),
#  (153, '🌙', '1F319', 'CRESCENT MOON', 18660409),
#  (154, '🌈', '1F308', 'RAINBOW', 18526942),
#  (155, '🙇', '1F647', 'PERSON BOWING DEEPLY', 18401543),
#  (156, '☁️', '2601', 'CLOUD', 18384980),
#  (157, '🎥', '1F3A5', 'MOVIE CAMERA', 18307724),
#  (158, '😧', '1F627', 'ANGUISHED FACE', 17873634),
#  (159, '🍻', '1F37B', 'CLINKING BEER MUGS', 17856004),
#  (160, '💟', '1F49F', 'HEART DECORATION', 17744964),
#  (161, '👯', '1F46F', 'WOMAN WITH BUNNY EARS', 17578783),
#  (162, '👼', '1F47C', 'BABY ANGEL', 17173535),
#  (163, '☕️', '2615', 'HOT BEVERAGE', 16880965),
#  (164, '🎁', '1F381', 'WRAPPED PRESENT', 16795638),
#  (165, '🍂', '1F342', 'FALLEN LEAF', 16784680),
#  (166, '💝', '1F49D', 'HEART WITH RIBBON', 16781072),
#  (167, '🌷', '1F337', 'TULIP', 16766557),
#  (168, '🐶', '1F436', 'DOG FACE', 16522128),
#  (169, '🌻', '1F33B', 'SUNFLOWER', 16151764),
#  (170, '💰', '1F4B0', 'MONEY BAG', 16128840),
#  (171, '💐', '1F490', 'BOUQUET', 15857732),
#  (172, '☎️', '260E', 'BLACK TELEPHONE', 15727796),
#  (173, '🌿', '1F33F', 'HERB', 15650967),
#  (174, '🎂', '1F382', 'BIRTHDAY CAKE', 15416571),
#  (175, '😮', '1F62E', 'FACE WITH OPEN MOUTH', 15326935),
#  (176, '🏃', '1F3C3', 'RUNNER', 14962904),
#  (177, '🌎', '1F30E', 'EARTH GLOBE AMERICAS', 14865933),
#  (178, '🌍', '1F30D', 'EARTH GLOBE EUROPE-AFRICA', 14620668),
#  (179, '♨️', '2668', 'HOT SPRINGS', 14517841),
#  (180, '⚓️', '2693', 'ANCHOR', 14492770),
#  (181, '😵', '1F635', 'DIZZY FACE', 14411468),
#  (182, '✖️', '2716', 'HEAVY MULTIPLICATION X', 14355036),
#  (183, '🇺🇸', '1F1FA-1F1F8', 'REGIONAL INDICATOR SYMBOL LETTERS US', 14241200),
#  (184, '😲', '1F632', 'ASTONISHED FACE', 14230304),
#  (185, '🐱', '1F431', 'CAT FACE', 13996437),
#  (186, '♣️', '2663', 'BLACK CLUB SUIT', 13992835),
#  (187, '😯', '1F62F', 'HUSHED FACE', 13971612),
#  (188, '🎄', '1F384', 'CHRISTMAS TREE', 13830952),
#  (189, '👫', '1F46B', 'MAN AND WOMAN HOLDING HANDS', 13688741),
#  (190, '👆', '1F446', 'WHITE UP POINTING BACKHAND INDEX', 13516574),
#  (191, '🏀', '1F3C0', 'BASKETBALL AND HOOP', 13500215),
#  (192, '🏆', '1F3C6', 'TROPHY', 13267464),
#  (193, '🌝', '1F31D', 'FULL MOON WITH FACE', 13266112),
#  (194, '💸', '1F4B8', 'MONEY WITH WINGS', 13010732),
#  (195, '💍', '1F48D', 'RING', 12772729),
#  (196, '😿', '1F63F', 'CRYING CAT FACE', 12676941),
#  (197, '🌼', '1F33C', 'BLOSSOM', 12080702),
#  (198, '💨', '1F4A8', 'DASH SYMBOL', 11992827),
#  (199, '👭', '1F46D', 'TWO WOMEN HOLDING HANDS', 11857675),
#  (200, '🍁', '1F341', 'MAPLE LEAF', 11783406),
#  (201, '💏', '1F48F', 'KISS', 11567813),
#  (202, '🙉', '1F649', 'HEAR-NO-EVIL MONKEY', 11361312),
#  (203, '🎊', '1F38A', 'CONFETTI BALL', 11297801),
#  (204, '💌', '1F48C', 'LOVE LETTER', 11019909),
#  (205, '👸', '1F478', 'PRINCESS', 10964018),
#  (206, '🌊', '1F30A', 'WATER WAVE', 10881389),
#  (207, '🎼', '1F3BC', 'MUSICAL SCORE', 10874758),
#  (208, '🌵', '1F335', 'CACTUS', 10847035),
#  (209, '🚀', '1F680', 'ROCKET', 10455012),
#  (210, '💆', '1F486', 'FACE MASSAGE', 10398093),
#  (211, '👄', '1F444', 'MOUTH', 10391604),
#  (212, '⏩', '23E9', 'BLACK RIGHT-POINTING DOUBLE TRIANGLE', 10255757),
#  (213, '🎬', '1F3AC', 'CLAPPER BOARD', 10244288),
#  (214, '📹', '1F4F9', 'VIDEO CAMERA', 10243913),
#  (215, '😦', '1F626', 'FROWNING FACE WITH OPEN MOUTH', 10113351),
#  (216, '☔️', '2614', 'UMBRELLA WITH RAIN DROPS', 10064927),
#  (217, '💣', '1F4A3', 'BOMB', 9910291),
#  (218, '🔪', '1F52A', 'HOCHO', 9862387),
#  (219, '🐷', '1F437', 'PIG FACE', 9686350),
#  (220, '🙍', '1F64D', 'PERSON FROWNING', 9553053),
#  (221, '👿', '1F47F', 'IMP', 9368971),
#  (222, '💑', '1F491', 'COUPLE WITH HEART', 9313917),
#  (223, '🔝', '1F51D', 'TOP WITH UPWARDS ARROW ABOVE', 9262736),
#  (224, '😽', '1F63D', 'KISSING CAT FACE WITH CLOSED EYES', 9227046),
#  (225, '🍩', '1F369', 'DOUGHNUT', 9053613),
#  (226, '🐝', '1F41D', 'HONEYBEE', 9043228),
#  (227, '🍟', '1F35F', 'FRENCH FRIES', 8935863),
#  (228, '🍭', '1F36D', 'LOLLIPOP', 8928583),
#  (229, '📲', '1F4F2', 'MOBILE PHONE WITH RIGHTWARDS ARROW AT LEFT', 8852071),
#  (230, '🌀', '1F300', 'CYCLONE', 8834743),
#  (231, '🏈', '1F3C8', 'AMERICAN FOOTBALL', 8834538),
#  (232, '💢', '1F4A2', 'ANGER SYMBOL', 8763388),
#  (233, '⚠️', '26A0', 'WARNING SIGN', 8664592),
#  (234, '🎅', '1F385', 'FATHER CHRISTMAS', 8595685),
#  (235, '😸', '1F638', 'GRINNING CAT FACE WITH SMILING EYES', 8552630),
#  (236, '🆗', '1F197', 'SQUARED OK', 8506304),
#  (237, '♦️', '2666', 'BLACK DIAMOND SUIT', 8412177),
#  (238, '📱', '1F4F1', 'MOBILE PHONE', 8401538),
#  (239, '🐼', '1F43C', 'PANDA FACE', 8347653),
#  (240, '🌏', '1F30F', 'EARTH GLOBE ASIA-AUSTRALIA', 8287288),
#  (241, '🍓', '1F353', 'STRAWBERRY', 8241247),
#  (242, '♠️', '2660', 'BLACK SPADE SUIT', 8236997),
#  (243, '😼', '1F63C', 'CAT FACE WITH WRY SMILE', 8096307),
#  (244, '🎸', '1F3B8', 'GUITAR', 8019155),
#  (245, '🐰', '1F430', 'RABBIT FACE', 8009459),
#  (246, '💬', '1F4AC', 'SPEECH BALLOON', 7901759),
#  (247, '🍆', '1F346', 'AUBERGINE', 7793976),
#  (248, '🍑', '1F351', 'PEACH', 7790868),
#  (249, '😗', '1F617', 'KISSING FACE', 7784939),
#  (250, '🍷', '1F377', 'WINE GLASS', 7778869),
#  (251, '🙀', '1F640', 'WEARY CAT FACE', 7767828),
#  (252, '🍺', '1F37A', 'BEER MUG', 7708559),
#  (253, '🍉', '1F349', 'WATERMELON', 7641587),
#  (254, '🍌', '1F34C', 'BANANA', 7630613),
#  (255, '🚨', '1F6A8', 'POLICE CARS REVOLVING LIGHT', 7573741),
#  (256, '⛄️', '26C4', 'SNOWMAN WITHOUT SNOW', 7486371),
#  (257, '🍴', '1F374', 'FORK AND KNIFE', 7439874),
#  (258, '👶', '1F476', 'BABY', 7314292),
#  (259, '📺', '1F4FA', 'TELEVISION', 7273430),
#  (260, '🐾', '1F43E', 'PAW PRINTS', 7238677),
#  (261, '🍒', '1F352', 'CHERRIES', 7206196),
#  (262, '🔮', '1F52E', 'CRYSTAL BALL', 7191109),
#  (263, '🐸', '1F438', 'FROG FACE', 7118436),
#  (264, '⭕️', '2B55', 'HEAVY LARGE CIRCLE', 7064569),
#  (265, '🍹', '1F379', 'TROPICAL DRINK', 7035908),
#  (266, '🐍', '1F40D', 'SNAKE', 6993359),
#  (267, '👣', '1F463', 'FOOTPRINTS', 6979682),
#  (268, '🚮', '1F6AE', 'PUT LITTER IN ITS PLACE SYMBOL', 6969156),
#  (269, '🌾', '1F33E', 'EAR OF RICE', 6961497),
#  (270, '⛅️', '26C5', 'SUN BEHIND CLOUD', 6960553),
#  (271, '⬇️', '2B07', 'DOWNWARDS BLACK ARROW', 6792686),
#  (272, '🚗', '1F697', 'AUTOMOBILE', 6781740),
#  (273, '🚬', '1F6AC', 'SMOKING SYMBOL', 6697095),
#  (274, '🔸', '1F538', 'SMALL ORANGE DIAMOND', 6654159),
#  (275, '🐻', '1F43B', 'BEAR FACE', 6651897),
#  (276, '🐣', '1F423', 'HATCHING CHICK', 6527437),
#  (277, '🌌', '1F30C', 'MILKY WAY', 6489378),
#  (278, '🐢', '1F422', 'TURTLE', 6249991),
#  (279, '📞', '1F4DE', 'TELEPHONE RECEIVER', 6249324),
#  (280, '🎃', '1F383', 'JACK-O-LANTERN', 6220293),
#  (281, '🎯', '1F3AF', 'DIRECT HIT', 6217821),
#  (282, '👾', '1F47E', 'ALIEN MONSTER', 6209822),
#  (283, '🍔', '1F354', 'HAMBURGER', 6137317),
#  (284, '🛃', '1F6C3', 'CUSTOMS', 6132546),
#  (285, '🐯', '1F42F', 'TIGER FACE', 6091396),
#  (286, '↔️', '2194', 'LEFT RIGHT ARROW', 6080950),
#  (287, '📢', '1F4E2', 'PUBLIC ADDRESS LOUDSPEAKER', 6072737),
#  (288, '😺', '1F63A', 'SMILING CAT FACE WITH OPEN MOUTH', 6022558),
#  (289, '🔊', '1F50A', 'SPEAKER WITH THREE SOUND WAVES', 5993164),
#  (290, '🍫', '1F36B', 'CHOCOLATE BAR', 5988745),
#  (291, '📝', '1F4DD', 'MEMO', 5985887),
#  (292, '🍦', '1F366', 'SOFT ICE CREAM', 5924778),
#  (293, '™', '2122', 'TRADE MARK SIGN', 5920599),
#  (294, '🍬', '1F36C', 'CANDY', 5919213),
#  (295, '🌱', '1F331', 'SEEDLING', 5873746),
#  (296, '🍸', '1F378', 'COCKTAIL GLASS', 5818523),
#  (297, '💉', '1F489', 'SYRINGE', 5786902),
#  (298, '📚', '1F4DA', 'BOOKS', 5776726),
#  (299, '🍍', '1F34D', 'PINEAPPLE', 5714551),
#  (300, '🚫', '1F6AB', 'NO ENTRY SIGN', 5611801),
#  (301, '🎮', '1F3AE', 'VIDEO GAME', 5544059),
#  (302, '🐥', '1F425', 'FRONT-FACING BABY CHICK', 5525128),
#  (303, '®', '00AE', 'REGISTERED SIGN', 5519501),
#  (304, '🐙', '1F419', 'OCTOPUS', 5518537),
#  (305, '🍰', '1F370', 'SHORTCAKE', 5477968),
#  (306, '📕', '1F4D5', 'CLOSED BOOK', 5464147),
#  (307, '🍇', '1F347', 'GRAPES', 5454976),
#  (308, '📍', '1F4CD', 'ROUND PUSHPIN', 5448741),
#  (309, '▪️', '25AA', 'BLACK SMALL SQUARE', 5436942),
#  (310, '💄', '1F484', 'LIPSTICK', 5345908),
#  (311, '🐳', '1F433', 'SPOUTING WHALE', 5345769),
#  (312, '💊', '1F48A', 'PILL', 5267189),
#  (313, '🐐', '1F410', 'GOAT', 5255182),
#  (314, '⚾️', '26BE', 'BASEBALL', 5169040),
#  (315, '✂️', '2702', 'BLACK SCISSORS', 5158305),
#  (316, '✏️', '270F', 'PENCIL', 5095021),
#  (317, '💿', '1F4BF', 'OPTICAL DISC', 5084385),
#  (318, '🍪', '1F36A', 'COOKIE', 5034979),
#  (319, '🐒', '1F412', 'MONKEY', 4991760),
#  (320, '🇫🇷', '1F1EB-1F1F7', 'REGIONAL INDICATOR SYMBOL LETTERS FR', 4983372),
#  (321, '👩', '1F469', 'WOMAN', 4969910),
#  (322, '🐬', '1F42C', 'DOLPHIN', 4967794),
#  (323, '💡', '1F4A1', 'ELECTRIC LIGHT BULB', 4942240),
#  (324, '🔑', '1F511', 'KEY', 4917493),
#  (325, '👹', '1F479', 'JAPANESE OGRE', 4816596),
#  (326, '👨', '1F468', 'MAN', 4805682),
#  (327, '3️⃣', '0033-20E3', 'KEYCAP 3', 4787455),
#  (328, '🏡', '1F3E1', 'HOUSE WITH GARDEN', 4765013),
#  (329, '🎓', '1F393', 'GRADUATION CAP', 4734934),
#  (330, '👧', '1F467', 'GIRL', 4730264),
#  (331, '💻', '1F4BB', 'PERSONAL COMPUTER', 4684663),
#  (332, '🎆', '1F386', 'FIREWORKS', 4639540),
#  (333, '💧', '1F4A7', 'DROPLET', 4638556),
#  (334, '🌠', '1F320', 'SHOOTING STAR', 4619987),
#  (335, '🆘', '1F198', 'SQUARED SOS', 4493821),
#  (336, '🍎', '1F34E', 'RED APPLE', 4472861),
#  (337, '👙', '1F459', 'BIKINI', 4435764),
#  (338, '🔃', '1F503', 'CLOCKWISE DOWNWARDS AND UPWARDS OPEN CIRCLE ARROWS', 4392008),
#  (339, '❓', '2753', 'BLACK QUESTION MARK ORNAMENT', 4353932),
#  (340, '👠', '1F460', 'HIGH-HEELED SHOE', 4343472),
#  (341, '🆓', '1F193', 'SQUARED FREE', 4311841),
#  (342, '😾', '1F63E', 'POUTING CAT FACE', 4302884),
#  (343, '📖', '1F4D6', 'OPEN BOOK', 4299960),
#  (344, '🔵', '1F535', 'LARGE BLUE CIRCLE', 4266142),
#  (345, '💂', '1F482', 'GUARDSMAN', 4148238),
#  (346, '🇬🇧', '1F1EC-1F1E7', 'REGIONAL INDICATOR SYMBOL LETTERS GB', 4132413),
#  (347, '💵', '1F4B5', 'BANKNOTE WITH DOLLAR SIGN', 4105142),
#  (348, '🐘', '1F418', 'ELEPHANT', 4092834),
#  (349, '🏊', '1F3CA', 'SWIMMER', 4088615),
#  (350, '🍄', '1F344', 'MUSHROOM', 4085714),
#  (351, '🆒', '1F192', 'SQUARED COOL', 4023226),
#  (352, '♋️', '264B', 'CANCER', 4019078),
#  (353, '🚦', '1F6A6', 'VERTICAL TRAFFIC LIGHT', 4017439),
#  (354, '📣', '1F4E3', 'CHEERING MEGAPHONE', 4010131),
#  (355, '👪', '1F46A', 'FAMILY', 3953108),
#  (356, '📥', '1F4E5', 'INBOX TRAY', 3934286),
#  (357, '🍊', '1F34A', 'TANGERINE', 3879318),
#  (358, '📌', '1F4CC', 'PUSHPIN', 3878962),
#  (359, '🔐', '1F510', 'CLOSED LOCK WITH KEY', 3820002),
#  (360, '🔙', '1F519', 'BACK WITH LEFTWARDS ARROW ABOVE', 3786394),
#  (361, '👦', '1F466', 'BOY', 3775818),
#  (362, '⚪️', '26AA', 'MEDIUM WHITE CIRCLE', 3761724),
#  (363, '🌅', '1F305', 'SUNRISE', 3756441),
#  (364, '🐦', '1F426', 'BIRD', 3654011),
#  (365, '💇', '1F487', 'HAIRCUT', 3645196),
#  (366, '⚫️', '26AB', 'MEDIUM BLACK CIRCLE', 3638784),
#  (367, '🍗', '1F357', 'POULTRY LEG', 3637323),
#  (368, '🇮🇹', '1F1EE-1F1F9', 'REGIONAL INDICATOR SYMBOL LETTERS IT', 3636954),
#  (369, '🛅', '1F6C5', 'LEFT LUGGAGE', 3595712),
#  (370, '🏠', '1F3E0', 'HOUSE BUILDING', 3581537),
#  (371, '📻', '1F4FB', 'RADIO', 3572593),
#  (372, '🌃', '1F303', 'NIGHT WITH STARS', 3529635),
#  (373, '👓', '1F453', 'EYEGLASSES', 3520533),
#  (374, '🚘', '1F698', 'ONCOMING AUTOMOBILE', 3493035),
#  (375, '⏰', '23F0', 'ALARM CLOCK', 3443794),
#  (376, '🌲', '1F332', 'EVERGREEN TREE', 3385119),
#  (377, '↘️', '2198', 'SOUTH EAST ARROW', 3384630),
#  (378, '🎨', '1F3A8', 'ARTIST PALETTE', 3372360),
#  (379, '🎭', '1F3AD', 'PERFORMING ARTS', 3336403),
#  (380, '🐵', '1F435', 'MONKEY FACE', 3325854),
#  (381, '⌚️', '231A', 'WATCH', 3316363),
#  (382, '⬆️', '2B06', 'UPWARDS BLACK ARROW', 3295987),
#  (383, '4️⃣', '0034-20E3', 'KEYCAP 4', 3275385),
#  (384, '🙎', '1F64E', 'PERSON WITH POUTING FACE', 3259556),
#  (385, '🍋', '1F34B', 'LEMON', 3254093),
#  (386, '🌛', '1F31B', 'FIRST QUARTER MOON WITH FACE', 3239123),
#  (387, '↗️', '2197', 'NORTH EAST ARROW', 3237540),
#  (388, '🍧', '1F367', 'SHAVED ICE', 3221328),
#  (389, '🐟', '1F41F', 'FISH', 3218901),
#  (390, '✉️', '2709', 'ENVELOPE', 3188878),
#  (391, '🏁', '1F3C1', 'CHEQUERED FLAG', 3139204),
#  (392, '👬', '1F46C', 'TWO MEN HOLDING HANDS', 3130007),
#  (393, '✳️', '2733', 'EIGHT SPOKED ASTERISK', 3097535),
#  (394, '🔁', '1F501', 'CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS', 3089522),
#  (395, '🔹', '1F539', 'SMALL BLUE DIAMOND', 3086250),
#  (396, '👵', '1F475', 'OLDER WOMAN', 3071985),
#  (397, '⤵️', '2935', 'ARROW POINTING RIGHTWARDS THEN CURVING DOWNWARDS', 3059474),
#  (398, '🍼', '1F37C', 'BABY BOTTLE', 3052921),
#  (399, '🐠', '1F420', 'TROPICAL FISH', 3048289),
#  (400, '👟', '1F45F', 'ATHLETIC SHOE', 2979762),
#  (401, '🌑', '1F311', 'NEW MOON SYMBOL', 2978068),
#  (402, '🆙', '1F199', 'SQUARED UP WITH EXCLAMATION MARK', 2977926),
#  (403, '🍝', '1F35D', 'SPAGHETTI', 2967129),
#  (404, '🌜', '1F31C', 'LAST QUARTER MOON WITH FACE', 2927306),
#  (405, '❕', '2755', 'WHITE EXCLAMATION MARK ORNAMENT', 2914840),
#  (406, '🌕', '1F315', 'FULL MOON SYMBOL', 2911341),
#  (407, '🆕', '1F195', 'SQUARED NEW', 2864359),
#  (408, '🐽', '1F43D', 'PIG NOSE', 2853555),
#  (409, '♐️', '2650', 'SAGITTARIUS', 2848253),
#  (410, '👰', '1F470', 'BRIDE WITH VEIL', 2799890),
#  (411, '⏪', '23EA', 'BLACK LEFT-POINTING DOUBLE TRIANGLE', 2796191),
#  (412, '🎾', '1F3BE', 'TENNIS RACQUET AND BALL', 2774060),
#  (413, '🍥', '1F365', 'FISH CAKE WITH SWIRL DESIGN', 2767473),
#  (414, '⛽️', '26FD', 'FUEL PUMP', 2758643),
#  (415, '👂', '1F442', 'EAR', 2757165),
#  (416, '5️⃣', '0035-20E3', 'KEYCAP 5', 2752946),
#  (417, '🎩', '1F3A9', 'TOP HAT', 2751441),
#  (418, '🎇', '1F387', 'FIREWORK SPARKLER', 2728388),
#  (419, '🐺', '1F43A', 'WOLF FACE', 2690776),
#  (420, '👗', '1F457', 'DRESS', 2688740),
#  (421, '🍜', '1F35C', 'STEAMING BOWL', 2677414),
#  (422, '🐨', '1F428', 'KOALA', 2648949),
#  (423, '🌳', '1F333', 'DECIDUOUS TREE', 2648553),
#  (424, '🐴', '1F434', 'HORSE FACE', 2645608),
#  (425, '👃', '1F443', 'NOSE', 2630350),
#  (426, '🎐', '1F390', 'WIND CHIME', 2585070),
#  (427, '🔗', '1F517', 'LINK SYMBOL', 2569493),
#  (428, '🔜', '1F51C', 'SOON WITH RIGHTWARDS ARROW ABOVE', 2545941),
#  (429, '👳', '1F473', 'MAN WITH TURBAN', 2514774),
#  (430, '🍳', '1F373', 'COOKING', 2512926),
#  (431, '⛳️', '26F3', 'FLAG IN HOLE', 2511511),
#  (432, '↙️', '2199', 'SOUTH WEST ARROW', 2508169),
#  (433, '🐔', '1F414', 'CHICKEN', 2496996),
#  (434, '⁉️', '2049', 'EXCLAMATION QUESTION MARK', 2479622),
#  (435, '🐛', '1F41B', 'BUG', 2478479),
#  (436, '🚿', '1F6BF', 'SHOWER', 2461567),
#  (437, '❇️', '2747', 'SPARKLE', 2458520),
#  (438, '🌽', '1F33D', 'EAR OF MAIZE', 2448461),
#  (439, '🇪🇸', '1F1EA-1F1F8', 'REGIONAL INDICATOR SYMBOL LETTERS ES', 2416288),
#  (440, '🐮', '1F42E', 'COW FACE', 2384151),
#  (441, '🗿', '1F5FF', 'MOYAI', 2373958),
#  (442, '👴', '1F474', 'OLDER MAN', 2347119),
#  (443, '✴️', '2734', 'EIGHT POINTED BLACK STAR', 2344631),
#  (444, '⛔️', '26D4', 'NO ENTRY', 2319132),
#  (445, 'Ⓜ️', '24C2', 'CIRCLED LATIN CAPITAL LETTER M', 2293054),
#  (446, '👤', '1F464', 'BUST IN SILHOUETTE', 2286035),
#  (447, '🔋', '1F50B', 'BATTERY', 2281604),
#  (448, '🔘', '1F518', 'RADIO BUTTON', 2253318),
#  (449, '🐋', '1F40B', 'WHALE', 2245767),
#  (450, '🍞', '1F35E', 'BREAD', 2223593),
#  (451, '🔺', '1F53A', 'UP-POINTING RED TRIANGLE', 2221323),
#  (452, '🚙', '1F699', 'RECREATIONAL VEHICLE', 2212244),
#  (453, '🐹', '1F439', 'HAMSTER FACE', 2204088),
#  (454, '🚖', '1F696', 'ONCOMING TAXI', 2187107),
#  (455, '🚼', '1F6BC', 'BABY SYMBOL', 2181337),
#  (456, '🔻', '1F53B', 'DOWN-POINTING RED TRIANGLE', 2172900),
#  (457, '🐉', '1F409', 'DRAGON', 2162819),
#  (458, '🏄', '1F3C4', 'SURFER', 2141914),
#  (459, '🐭', '1F42D', 'MOUSE FACE', 2135739),
#  (460, '🔄', '1F504', 'ANTICLOCKWISE DOWNWARDS AND UPWARDS OPEN CIRCLE ARROWS', 2135197),
#  (461, '🍱', '1F371', 'BENTO BOX', 2133157),
#  (462, '🍵', '1F375', 'TEACUP WITHOUT HANDLE', 2126364),
#  (463, '↖️', '2196', 'NORTH WEST ARROW', 2117943),
#  (464, '⤴️', '2934', 'ARROW POINTING RIGHTWARDS THEN CURVING UPWARDS', 2107965),
#  (465, '🚩', '1F6A9', 'TRIANGULAR FLAG ON POST', 2107005),
#  (466, '👮', '1F46E', 'POLICE OFFICER', 2096954),
#  (467, '🔌', '1F50C', 'ELECTRIC PLUG', 2092157),
#  (468, '🔱', '1F531', 'TRIDENT EMBLEM', 2038606),
#  (469, '➰', '27B0', 'CURLY LOOP', 2038242),
#  (470, '➕', '2795', 'HEAVY PLUS SIGN', 2034986),
#  (471, '♒️', '2652', 'AQUARIUS', 2029417),
#  (472, '🐤', '1F424', 'BABY CHICK', 2022497),
#  (473, '🚲', '1F6B2', 'BICYCLE', 2022406),
#  (474, '🔒', '1F512', 'LOCK', 2018679),
#  (475, '🍣', '1F363', 'SUSHI', 1994986),
#  (476, '🔍', '1F50D', 'LEFT-POINTING MAGNIFYING GLASS', 1960935),
#  (477, '🍏', '1F34F', 'GREEN APPLE', 1959442),
#  (478, '🐞', '1F41E', 'LADY BEETLE', 1953701),
#  (479, '〰', '3030', 'WAVY DASH', 1952986),
#  (480, '🍅', '1F345', 'TOMATO', 1952755),
#  (481, '🐑', '1F411', 'SHEEP', 1951117),
#  (482, '🇩🇪', '1F1E9-1F1EA', 'REGIONAL INDICATOR SYMBOL LETTERS DE', 1944308),
#  (483, '🅰', '1F170', 'NEGATIVE SQUARED LATIN CAPITAL LETTER A', 1940680),
#  (484, '🐎', '1F40E', 'HORSE', 1940372),
#  (485, '🌒', '1F312', 'WAXING CRESCENT MOON SYMBOL', 1934434),
#  (486, '🔆', '1F506', 'HIGH BRIGHTNESS SYMBOL', 1923216),
#  (487, '🌄', '1F304', 'SUNRISE OVER MOUNTAINS', 1912711),
#  (488, '🎣', '1F3A3', 'FISHING POLE AND FISH', 1908961),
#  (489, '🍚', '1F35A', 'COOKED RICE', 1900258),
#  (490, '👥', '1F465', 'BUSTS IN SILHOUETTE', 1892977),
#  (491, '👺', '1F47A', 'JAPANESE GOBLIN', 1881053),
#  (492, '🔎', '1F50E', 'RIGHT-POINTING MAGNIFYING GLASS', 1868868),
#  (493, '0️⃣', '0030-20E3', 'KEYCAP 0', 1867768),
#  (494, '🔶', '1F536', 'LARGE ORANGE DIAMOND', 1865880),
#  (495, '🐕', '1F415', 'DOG', 1845727),
#  (496, '🌓', '1F313', 'FIRST QUARTER MOON SYMBOL', 1843794),
#  (497, '🕕', '1F555', 'CLOCK FACE SIX OCLOCK', 1828783),
#  (498, '🐇', '1F407', 'RABBIT', 1825684),
#  (499, '⌛️', '231B', 'HOURGLASS', 1816680),
#  (500, '🐓', '1F413', 'ROOSTER', 1816456),
#  (501, '👱', '1F471', 'PERSON WITH BLOND HAIR', 1805412),
#  (502, '⏳', '23F3', 'HOURGLASS WITH FLOWING SAND', 1800507),
#  (503, '🐈', '1F408', 'CAT', 1790045),
#  (504, '🌘', '1F318', 'WANING CRESCENT MOON SYMBOL', 1788770),
#  (505, '♏️', '264F', 'SCORPIUS', 1788449),
#  (506, '↕️', '2195', 'UP DOWN ARROW', 1785606),
#  (507, '💒', '1F492', 'WEDDING', 1780337),
#  (508, '♈️', '2648', 'ARIES', 1778886),
#  (509, '🔓', '1F513', 'OPEN LOCK', 1778091),
#  (510, '✒️', '2712', 'BLACK NIB', 1776232),
#  (511, '⛵️', '26F5', 'SAILBOAT', 1760140),
#  (512, '🍨', '1F368', 'ICE CREAM', 1746915),
#  (513, '〽️', '303D', 'PART ALTERNATION MARK', 1746339),
#  (514, '💲', '1F4B2', 'HEAVY DOLLAR SIGN', 1740212),
#  (515, '🌔', '1F314', 'WAXING GIBBOUS MOON SYMBOL', 1733740),
#  (516, '🍤', '1F364', 'FRIED SHRIMP', 1732926),
#  (517, '🈹', '1F239', 'SQUARED CJK UNIFIED IDEOGRAPH-5272', 1724856),
#  (518, '㊙️', '3299', 'CIRCLED IDEOGRAPH SECRET', 1723368),
#  (519, '👖', '1F456', 'JEANS', 1709260),
#  (520, '🌋', '1F30B', 'VOLCANO', 1704008),
#  (521, '📩', '1F4E9', 'ENVELOPE WITH DOWNWARDS ARROW ABOVE', 1694673),
#  (522, '🌗', '1F317', 'LAST QUARTER MOON SYMBOL', 1662624),
#  (523, '🐊', '1F40A', 'CROCODILE', 1661190),
#  (524, '🍯', '1F36F', 'HONEY POT', 1658335),
#  (525, '🅱', '1F171', 'NEGATIVE SQUARED LATIN CAPITAL LETTER B', 1651075),
#  (526, '🐚', '1F41A', 'SPIRAL SHELL', 1649990),
#  (527, '📛', '1F4DB', 'NAME BADGE', 1633850),
#  (528, '🔔', '1F514', 'BELL', 1618791),
#  (529, '💮', '1F4AE', 'WHITE FLOWER', 1617519),
#  (530, '🎹', '1F3B9', 'MUSICAL KEYBOARD', 1614364),
#  (531, '🍖', '1F356', 'MEAT ON BONE', 1608976),
#  (532, '👕', '1F455', 'T-SHIRT', 1597121),
#  (533, '♉️', '2649', 'TAURUS', 1596371),
#  (534, '➖', '2796', 'HEAVY MINUS SIGN', 1591866),
#  (535, '🔨', '1F528', 'HAMMER', 1588688),
#  (536, '🌖', '1F316', 'WANING GIBBOUS MOON SYMBOL', 1583467),
#  (537, '🌐', '1F310', 'GLOBE WITH MERIDIANS', 1583292),
#  (538, '♓️', '2653', 'PISCES', 1556948),
#  (539, '🏪', '1F3EA', 'CONVENIENCE STORE', 1554769),
#  (540, '📈', '1F4C8', 'CHART WITH UPWARDS TREND', 1554390),
#  (541, '♌️', '264C', 'LEO', 1542844),
#  (542, '6️⃣', '0036-20E3', 'KEYCAP 6', 1524157),
#  (543, '🗽', '1F5FD', 'STATUE OF LIBERTY', 1522817),
#  (544, '🐩', '1F429', 'POODLE', 1520213),
#  (545, '🐌', '1F40C', 'SNAIL', 1517562),
#  (546, '🛀', '1F6C0', 'BATH', 1516075),
#  (547, '🚌', '1F68C', 'BUS', 1515354),
#  (548, '🌆', '1F306', 'CITYSCAPE AT DUSK', 1515354),
#  (549, '👲', '1F472', 'MAN WITH GUA PI MAO', 1506439),
#  (550, '🌰', '1F330', 'CHESTNUT', 1484170),
#  (551, '🎱', '1F3B1', 'BILLIARDS', 1482519),
#  (552, '👔', '1F454', 'NECKTIE', 1477554),
#  (553, '🍲', '1F372', 'POT OF FOOD', 1477076),
#  (554, '🚺', '1F6BA', 'WOMENS SYMBOL', 1452227),
#  (555, '♊️', '264A', 'GEMINI', 1452211),
#  (556, '🇯🇵', '1F1EF-1F1F5', 'REGIONAL INDICATOR SYMBOL LETTERS JP', 1445643),
#  (557, '🎻', '1F3BB', 'VIOLIN', 1431483),
#  (558, '🌇', '1F307', 'SUNSET OVER BUILDINGS', 1415694),
#  (559, '🐜', '1F41C', 'ANT', 1412961),
#  (560, '🍛', '1F35B', 'CURRY AND RICE', 1405810),
#  (561, '🏨', '1F3E8', 'HOTEL', 1404678),
#  (562, '💠', '1F4A0', 'DIAMOND SHAPE WITH A DOT INSIDE', 1401912),
#  (563, '🎋', '1F38B', 'TANABATA TREE', 1397594),
#  (564, '🔛', '1F51B', 'ON WITH EXCLAMATION MARK WITH LEFT RIGHT ARROW ABOVE', 1396067),
#  (565, '🚂', '1F682', 'STEAM LOCOMOTIVE', 1388806),
#  (566, '♑️', '2651', 'CAPRICORN', 1385110),
#  (567, '🐲', '1F432', 'DRAGON FACE', 1364156),
#  (568, '📀', '1F4C0', 'DVD', 1362350),
#  (569, '7️⃣', '0037-20E3', 'KEYCAP 7', 1357521),
#  (570, '㊗️', '3297', 'CIRCLED IDEOGRAPH CONGRATULATION', 1355908),
#  (571, '🏂', '1F3C2', 'SNOWBOARDER', 1349600),
#  (572, '❎', '274E', 'NEGATIVE SQUARED CROSS MARK', 1347483),
#  (573, '📆', '1F4C6', 'TEAR-OFF CALENDAR', 1331649),
#  (574, '🍐', '1F350', 'PEAR', 1322593),
#  (575, '🔷', '1F537', 'LARGE BLUE DIAMOND', 1313049),
#  (576, '🎲', '1F3B2', 'GAME DIE', 1301222),
#  (577, '⛪️', '26EA', 'CHURCH', 1272102),
#  (578, '🚴', '1F6B4', 'BICYCLIST', 1260954),
#  (579, '🎷', '1F3B7', 'SAXOPHONE', 1256754),
#  (580, '📅', '1F4C5', 'CALENDAR', 1242197),
#  (581, '📦', '1F4E6', 'PACKAGE', 1221171),
#  (582, '🍮', '1F36E', 'CUSTARD', 1221160),
#  (583, '🏥', '1F3E5', 'HOSPITAL', 1214783),
#  (584, '🎌', '1F38C', 'CROSSED FLAGS', 1208586),
#  (585, '📰', '1F4F0', 'NEWSPAPER', 1202910),
#  (586, '🅾', '1F17E', 'NEGATIVE SQUARED LATIN CAPITAL LETTER O', 1198425),
#  (587, '🌂', '1F302', 'CLOSED UMBRELLA', 1186906),
#  (588, '🆔', '1F194', 'SQUARED ID', 1186617),
#  (589, '🏢', '1F3E2', 'OFFICE BUILDING', 1183801),
#  (590, '🆚', '1F19A', 'SQUARED VS', 1176324),
#  (591, '🚪', '1F6AA', 'DOOR', 1174519),
#  (592, '🗻', '1F5FB', 'MOUNT FUJI', 1173205),
#  (593, '🎎', '1F38E', 'JAPANESE DOLLS', 1167957),
#  (594, '🐖', '1F416', 'PIG', 1156969),
#  (595, '🎺', '1F3BA', 'TRUMPET', 1156954),
#  (596, '🎳', '1F3B3', 'BOWLING', 1152959),
#  (597, '❔', '2754', 'WHITE QUESTION MARK ORNAMENT', 1142912),
#  (598, '♍️', '264D', 'VIRGO', 1142612),
#  (599, '🐫', '1F42B', 'BACTRIAN CAMEL', 1141760),
#  (600, '🏩', '1F3E9', 'LOVE HOTEL', 1129490),
#  (601, '♎️', '264E', 'LIBRA', 1129226),
#  (602, '🍡', '1F361', 'DANGO', 1120224),
#  (603, '🔽', '1F53D', 'DOWN-POINTING SMALL RED TRIANGLE', 1112245),
#  (604, '👞', '1F45E', 'MANS SHOE', 1107828),
#  (605, '🔰', '1F530', 'JAPANESE SYMBOL FOR BEGINNER', 1107460),
#  (606, '👒', '1F452', 'WOMANS HAT', 1106660),
#  (607, '🔕', '1F515', 'BELL WITH CANCELLATION STROKE', 1099929),
#  (608, '🚔', '1F694', 'ONCOMING POLICE CAR', 1092981),
#  (609, '🚽', '1F6BD', 'TOILET', 1088465),
#  (610, '🏫', '1F3EB', 'SCHOOL', 1086247),
#  (611, '👜', '1F45C', 'HANDBAG', 1085348),
#  (612, '🐄', '1F404', 'COW', 1073664),
#  (613, '💳', '1F4B3', 'CREDIT CARD', 1072006),
#  (614, '🇷🇺', '1F1F7-1F1FA', 'REGIONAL INDICATOR SYMBOL LETTERS RU', 1064595),
#  (615, '🏉', '1F3C9', 'RUGBY FOOTBALL', 1047922),
#  (616, '🐀', '1F400', 'RAT', 1039544),
#  (617, '🚓', '1F693', 'POLICE CAR', 1029926),
#  (618, '🎡', '1F3A1', 'FERRIS WHEEL', 1020718),
#  (619, '🔼', '1F53C', 'UP-POINTING SMALL RED TRIANGLE', 1020247),
#  (620, '🐪', '1F42A', 'DROMEDARY CAMEL', 1006152),
#  (621, '🐡', '1F421', 'BLOWFISH', 997794),
#  (622, '🚣', '1F6A3', 'ROWBOAT', 996897),
#  (623, '👷', '1F477', 'CONSTRUCTION WORKER', 995766),
#  (624, '🍙', '1F359', 'RICE BALL', 994447),
#  (625, '🚢', '1F6A2', 'SHIP', 987591),
#  (626, '🅿️', '1F17F', 'NEGATIVE SQUARED LATIN CAPITAL LETTER P', 950990),
#  (627, '📴', '1F4F4', 'MOBILE PHONE OFF', 949734),
#  (628, '🐏', '1F40F', 'RAM', 947881),
#  (629, '🚒', '1F692', 'FIRE ENGINE', 947080),
#  (630, '💈', '1F488', 'BARBER POLE', 942816),
#  (631, '🚑', '1F691', 'AMBULANCE', 932525),
#  (632, '🗼', '1F5FC', 'TOKYO TOWER', 923623),
#  (633, '🃏', '1F0CF', 'PLAYING CARD BLACK JOKER', 918881),
#  (634, '👛', '1F45B', 'PURSE', 917471),
#  (635, '📡', '1F4E1', 'SATELLITE ANTENNA', 917255),
#  (636, '🏇', '1F3C7', 'HORSE RACING', 914713),
#  (637, '⏫', '23EB', 'BLACK UP-POINTING DOUBLE TRIANGLE', 908856),
#  (638, '🎢', '1F3A2', 'ROLLER COASTER', 907323),
#  (639, '👘', '1F458', 'KIMONO', 899047),
#  (640, '🎒', '1F392', 'SCHOOL SATCHEL', 897862),
#  (641, '💷', '1F4B7', 'BANKNOTE WITH POUND SIGN', 894163),
#  (642, 'ℹ️', '2139', 'INFORMATION SOURCE', 886912),
#  (643, '🚕', '1F695', 'TAXI', 880518),
#  (644, '🏰', '1F3F0', 'EUROPEAN CASTLE', 880424),
#  (645, '👢', '1F462', 'WOMANS BOOTS', 865913),
#  (646, '👚', '1F45A', 'WOMANS CLOTHES', 864164),
#  (647, '➿', '27BF', 'DOUBLE CURLY LOOP', 861001),
#  (648, '⛺️', '26FA', 'TENT', 857039),
#  (649, '🎪', '1F3AA', 'CIRCUS TENT', 847996),
#  (650, '🎫', '1F3AB', 'TICKET', 843346),
#  (651, '💼', '1F4BC', 'BRIEFCASE', 840679),
#  (652, '🐗', '1F417', 'BOAR', 838182),
#  (653, '🕛', '1F55B', 'CLOCK FACE TWELVE OCLOCK', 833330),
#  (654, '🐅', '1F405', 'TIGER', 831950),
#  (655, '🔚', '1F51A', 'END WITH LEFTWARDS ARROW ABOVE', 827213),
#  (656, '🔲', '1F532', 'BLACK SQUARE BUTTON', 827178),
#  (657, '▫️', '25AB', 'WHITE SMALL SQUARE', 826505),
#  (658, '8️⃣', '0038-20E3', 'KEYCAP 8', 826112),
#  (659, '🐂', '1F402', 'OX', 822781),
#  (660, '9️⃣', '0039-20E3', 'KEYCAP 9', 818899),
#  (661, '🚁', '1F681', 'HELICOPTER', 814040),
#  (662, '⏬', '23EC', 'BLACK DOWN-POINTING DOUBLE TRIANGLE', 814017),
#  (663, '🌉', '1F309', 'BRIDGE AT NIGHT', 805317),
#  (664, '🔦', '1F526', 'ELECTRIC TORCH', 802437),
#  (665, '🚚', '1F69A', 'DELIVERY TRUCK', 801856),
#  (666, '🍈', '1F348', 'MELON', 798093),
#  (667, '🌁', '1F301', 'FOGGY', 758363),
#  (668, '🕒', '1F552', 'CLOCK FACE THREE OCLOCK', 755495),
#  (669, '◾️', '25FE', 'BLACK MEDIUM SMALL SQUARE', 745337),
#  (670, '🚍', '1F68D', 'ONCOMING BUS', 741783),
#  (671, '👡', '1F461', 'WOMANS SANDAL', 734478),
#  (672, '🔳', '1F533', 'WHITE SQUARE BUTTON', 728278),
#  (673, '🚹', '1F6B9', 'MENS SYMBOL', 728276),
#  (674, '🔯', '1F52F', 'SIX POINTED STAR WITH MIDDLE DOT', 727097),
#  (675, '🕦', '1F566', 'CLOCK FACE ELEVEN-THIRTY', 722005),
#  (676, '💺', '1F4BA', 'SEAT', 712682),
#  (677, '🎍', '1F38D', 'PINE DECORATION', 709126),
#  (678, '🍠', '1F360', 'ROASTED SWEET POTATO', 707112),
#  (679, '🚧', '1F6A7', 'CONSTRUCTION SIGN', 677899),
#  (680, '🕐', '1F550', 'CLOCK FACE ONE OCLOCK', 672775),
#  (681, '🎰', '1F3B0', 'SLOT MACHINE', 671688),
#  (682, '🔅', '1F505', 'LOW BRIGHTNESS SYMBOL', 662669),
#  (683, '🇰🇷', '1F1F0-1F1F7', 'REGIONAL INDICATOR SYMBOL LETTERS KR', 662548),
#  (684, '◼️', '25FC', 'BLACK MEDIUM SQUARE', 658944),
#  (685, '📶', '1F4F6', 'ANTENNA WITH BARS', 657000),
#  (686, '🔟', '1F51F', 'KEYCAP TEN', 655408),
#  (687, '💽', '1F4BD', 'MINIDISC', 654749),
#  (688, '💶', '1F4B6', 'BANKNOTE WITH EURO SIGN', 650022),
#  (689, '📓', '1F4D3', 'NOTEBOOK', 644391),
#  (690, '🎏', '1F38F', 'CARP STREAMER', 642311),
#  (691, '🍢', '1F362', 'ODEN', 628465),
#  (692, '📮', '1F4EE', 'POSTBOX', 627375),
#  (693, '🍘', '1F358', 'RICE CRACKER', 620370),
#  (694, '🎠', '1F3A0', 'CAROUSEL HORSE', 619320),
#  (695, '📎', '1F4CE', 'PAPERCLIP', 616952),
#  (696, '⛎', '26CE', 'OPHIUCHUS', 614461),
#  (697, '🏤', '1F3E4', 'EUROPEAN POST OFFICE', 614435),
#  (698, '♿️', '267F', 'WHEELCHAIR SYMBOL', 605231),
#  (699, '🔇', '1F507', 'SPEAKER WITH CANCELLATION STROKE', 605109),
#  (700, '📬', '1F4EC', 'OPEN MAILBOX WITH RAISED FLAG', 603060),
#  (701, '📧', '1F4E7', 'E-MAIL SYMBOL', 601119),
#  (702, '💾', '1F4BE', 'FLOPPY DISK', 600039),
#  (703, '🕑', '1F551', 'CLOCK FACE TWO OCLOCK', 595163),
#  (704, '📒', '1F4D2', 'LEDGER', 593525),
#  (705, '🎿', '1F3BF', 'SKI AND SKI BOOT', 589453),
#  (706, '🐆', '1F406', 'LEOPARD', 586552),
#  (707, '🎑', '1F391', 'MOON VIEWING CEREMONY', 583052),
#  (708, '🏬', '1F3EC', 'DEPARTMENT STORE', 581087),
#  (709, '🍶', '1F376', 'SAKE BOTTLE AND CUP', 578469),
#  (710, '📉', '1F4C9', 'CHART WITH DOWNWARDS TREND', 578211),
#  (711, '⬜️', '2B1C', 'WHITE LARGE SQUARE', 578169),
#  (712, '#️⃣', '0023-20E3', 'HASH KEY', 572656),
#  (713, '🔭', '1F52D', 'TELESCOPE', 559445),
#  (714, '🏧', '1F3E7', 'AUTOMATED TELLER MACHINE', 558119),
#  (715, '🚃', '1F683', 'RAILWAY CAR', 550969),
#  (716, '📊', '1F4CA', 'BAR CHART', 545988),
#  (717, '🕓', '1F553', 'CLOCK FACE FOUR OCLOCK', 531776),
#  (718, '📼', '1F4FC', 'VIDEOCASSETTE', 531551),
#  (719, '🚄', '1F684', 'HIGH-SPEED TRAIN', 521950),
#  (720, '🐃', '1F403', 'WATER BUFFALO', 518672),
#  (721, '🎽', '1F3BD', 'RUNNING SHIRT WITH SASH', 514010),
#  (722, '📋', '1F4CB', 'CLIPBOARD', 508333),
#  (723, '🕔', '1F554', 'CLOCK FACE FIVE OCLOCK', 504550),
#  (724, '🚤', '1F6A4', 'SPEEDBOAT', 501674),
#  (725, '🎦', '1F3A6', 'CINEMA', 495891),
#  (726, '🔂', '1F502', 'CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS WITH CIRCLED ONE OVERLAY', 495874),
#  (727, '🕘', '1F558', 'CLOCK FACE NINE OCLOCK', 491858),
#  (728, '📨', '1F4E8', 'INCOMING ENVELOPE', 491300),
#  (729, '🚛', '1F69B', 'ARTICULATED LORRY', 490854),
#  (730, '💴', '1F4B4', 'BANKNOTE WITH YEN SIGN', 488626),
#  (731, '◻️', '25FB', 'WHITE MEDIUM SQUARE', 487149),
#  (732, '🚥', '1F6A5', 'HORIZONTAL TRAFFIC LIGHT', 486066),
#  (733, '⬛️', '2B1B', 'BLACK LARGE SQUARE', 485613),
#  (734, '🔧', '1F527', 'WRENCH', 485349),
#  (735, '📗', '1F4D7', 'GREEN BOOK', 478111),
#  (736, '🇨🇳', '1F1E8-1F1F3', 'REGIONAL INDICATOR SYMBOL LETTERS CN', 475233),
#  (737, '🕙', '1F559', 'CLOCK FACE TEN OCLOCK', 464852),
#  (738, '🏦', '1F3E6', 'BANK', 464468),
#  (739, '🕗', '1F557', 'CLOCK FACE EIGHT OCLOCK', 457623),
#  (740, '🚐', '1F690', 'MINIBUS', 445969),
#  (741, '🐁', '1F401', 'MOUSE', 445135),
#  (742, '📘', '1F4D8', 'BLUE BOOK', 444682),
#  (743, '⛲️', '26F2', 'FOUNTAIN', 440317),
#  (744, '🔈', '1F508', 'SPEAKER', 437364),
#  (745, '🔉', '1F509', 'SPEAKER WITH ONE SOUND WAVE', 427635),
#  (746, '🔬', '1F52C', 'MICROSCOPE', 426555),
#  (747, '🕖', '1F556', 'CLOCK FACE SEVEN OCLOCK', 425254),
#  (748, '🚜', '1F69C', 'TRACTOR', 422445),
#  (749, '💱', '1F4B1', 'CURRENCY EXCHANGE', 417513),
#  (750, '🛁', '1F6C1', 'BATHTUB', 417465),
#  (751, '🉐', '1F250', 'CIRCLED IDEOGRAPH ADVANTAGE', 411532),
#  (752, '📵', '1F4F5', 'NO MOBILE PHONES', 408600),
#  (753, '🏮', '1F3EE', 'IZAKAYA LANTERN', 408368),
#  (754, '🚇', '1F687', 'METRO', 408154),
#  (755, '📜', '1F4DC', 'SCROLL', 402425),
#  (756, '🕚', '1F55A', 'CLOCK FACE ELEVEN OCLOCK', 401693),
#  (757, '📳', '1F4F3', 'VIBRATION MODE', 401018),
#  (758, '🚾', '1F6BE', 'WATER CLOSET', 397383),
#  (759, '🔩', '1F529', 'NUT AND BOLT', 395556),
#  (760, '💹', '1F4B9', 'CHART WITH UPWARDS TREND AND YEN SIGN', 394203),
#  (761, '🆖', '1F196', 'SQUARED NG', 393019),
#  (762, '🚅', '1F685', 'HIGH-SPEED TRAIN WITH BULLET NOSE', 392780),
#  (763, '📄', '1F4C4', 'PAGE FACING UP', 388792),
#  (764, '🚭', '1F6AD', 'NO SMOKING SYMBOL', 386114),
#  (765, '🔖', '1F516', 'BOOKMARK', 375088),
#  (766, '🚉', '1F689', 'STATION', 369178),
#  (767, '🆎', '1F18E', 'NEGATIVE SQUARED AB', 353503),
#  (768, '🈯️', '1F22F', 'SQUARED CJK UNIFIED IDEOGRAPH-6307', 343722),
#  (769, '🚊', '1F68A', 'TRAM', 343336),
#  (770, '🏯', '1F3EF', 'JAPANESE CASTLE', 338328),
#  (771, '🚷', '1F6B7', 'NO PEDESTRIANS', 334737),
#  (772, '🚎', '1F68E', 'TROLLEYBUS', 331780),
#  (773, '◽️', '25FD', 'WHITE MEDIUM SMALL SQUARE', 321961),
#  (774, '🚵', '1F6B5', 'MOUNTAIN BICYCLIST', 318841),
#  (775, '📃', '1F4C3', 'PAGE WITH CURL', 312117),
#  (776, '🔀', '1F500', 'TWISTED RIGHTWARDS ARROWS', 308478),
#  (777, '📑', '1F4D1', 'BOOKMARK TABS', 299448),
#  (778, '🚻', '1F6BB', 'RESTROOM', 298447),
#  (779, '🚏', '1F68F', 'BUS STOP', 290156),
#  (780, '📠', '1F4E0', 'FAX MACHINE', 280563),
#  (781, '🏣', '1F3E3', 'JAPANESE POST OFFICE', 277905),
#  (782, '🎴', '1F3B4', 'FLOWER PLAYING CARDS', 277670),
#  (783, '📫', '1F4EB', 'CLOSED MAILBOX WITH RAISED FLAG', 276138),
#  (784, '🈳', '1F233', 'SQUARED CJK UNIFIED IDEOGRAPH-7A7A', 275552),
#  (785, '🕜', '1F55C', 'CLOCK FACE ONE-THIRTY', 273935),
#  (786, '👝', '1F45D', 'POUCH', 272385),
#  (787, '🏭', '1F3ED', 'FACTORY', 271968),
#  (788, '🕤', '1F564', 'CLOCK FACE NINE-THIRTY', 269042),
#  (789, '🚋', '1F68B', 'TRAM CAR', 267918),
#  (790, '🔏', '1F50F', 'LOCK WITH INK PEN', 267881),
#  (791, '📐', '1F4D0', 'TRIANGULAR RULER', 261650),
#  (792, '🚈', '1F688', 'LIGHT RAIL', 259220),
#  (793, '🆑', '1F191', 'SQUARED CL', 256014),
#  (794, '📯', '1F4EF', 'POSTAL HORN', 255209),
#  (795, '📙', '1F4D9', 'ORANGE BOOK', 253047),
#  (796, '🀄️', '1F004', 'MAHJONG TILE RED DRAGON', 249831),
#  (797, '🈺', '1F23A', 'SQUARED CJK UNIFIED IDEOGRAPH-55B6', 246462),
#  (798, '📪', '1F4EA', 'CLOSED MAILBOX WITH LOWERED FLAG', 245725),
#  (799, '🕝', '1F55D', 'CLOCK FACE TWO-THIRTY', 245588),
#  (800, '🚸', '1F6B8', 'CHILDREN CROSSING', 239609),
#  (801, '🚆', '1F686', 'TRAIN', 238479),
#  (802, '📔', '1F4D4', 'NOTEBOOK WITH DECORATIVE COVER', 234975),
#  (803, '🗾', '1F5FE', 'SILHOUETTE OF JAPAN', 233720),
#  (804, '📏', '1F4CF', 'STRAIGHT RULER', 229871),
#  (805, '🈶', '1F236', 'SQUARED CJK UNIFIED IDEOGRAPH-6709', 228852),
#  (806, '➗', '2797', 'HEAVY DIVISION SIGN', 228691),
#  (807, '🕥', '1F565', 'CLOCK FACE TEN-THIRTY', 226423),
#  (808, '🔢', '1F522', 'INPUT SYMBOL FOR NUMBERS', 225092),
#  (809, '🕞', '1F55E', 'CLOCK FACE THREE-THIRTY', 220790),
#  (810, '🕟', '1F55F', 'CLOCK FACE FOUR-THIRTY', 219646),
#  (811, '🕢', '1F562', 'CLOCK FACE SEVEN-THIRTY', 217264),
#  (812, '🈷', '1F237', 'SQUARED CJK UNIFIED IDEOGRAPH-6708', 217012),
#  (813, '🈚️', '1F21A', 'SQUARED CJK UNIFIED IDEOGRAPH-7121', 215918),
#  (814, '📤', '1F4E4', 'OUTBOX TRAY', 214860),
#  (815, '🈲', '1F232', 'SQUARED CJK UNIFIED IDEOGRAPH-7981', 214518),
#  (816, '🕠', '1F560', 'CLOCK FACE FIVE-THIRTY', 209687),
#  (817, '🕣', '1F563', 'CLOCK FACE EIGHT-THIRTY', 208421),
#  (818, '🉑', '1F251', 'CIRCLED IDEOGRAPH ACCEPT', 207948),
#  (819, '🈂', '1F202', 'SQUARED KATAKANA SA', 207723),
#  (820, '🈵', '1F235', 'SQUARED CJK UNIFIED IDEOGRAPH-6E80', 206902),
#  (821, '📭', '1F4ED', 'OPEN MAILBOX WITH LOWERED FLAG', 206054),
#  (822, '🈸', '1F238', 'SQUARED CJK UNIFIED IDEOGRAPH-7533', 205818),
#  (823, '📂', '1F4C2', 'OPEN FILE FOLDER', 203814),
#  (824, '📟', '1F4DF', 'PAGER', 198324),
#  (825, '🕡', '1F561', 'CLOCK FACE SIX-THIRTY', 194108),
#  (826, '🈴', '1F234', 'SQUARED CJK UNIFIED IDEOGRAPH-5408', 188686),
#  (827, '📁', '1F4C1', 'FILE FOLDER', 165858),
#  (828, '🚰', '1F6B0', 'POTABLE WATER SYMBOL', 155687),
#  (829, '🚝', '1F69D', 'MONORAIL', 152153),
#  (830, '📇', '1F4C7', 'CARD INDEX', 148824),
#  (831, '🕧', '1F567', 'CLOCK FACE TWELVE-THIRTY', 148285),
#  (832, '🚯', '1F6AF', 'DO NOT LITTER SYMBOL', 131087),
#  (833, '🚳', '1F6B3', 'NO BICYCLES', 129009),
#  (834, '🚞', '1F69E', 'MOUNTAIN RAILWAY', 127573),
#  (835, '🔤', '1F524', 'INPUT SYMBOL FOR LATIN LETTERS', 125167),
#  (836, '🛄', '1F6C4', 'BAGGAGE CLAIM', 122307),
#  (837, '🔣', '1F523', 'INPUT SYMBOL FOR SYMBOLS', 121047),
#  (838, '🈁', '1F201', 'SQUARED KATAKANA KOKO', 111239),
#  (839, '🚠', '1F6A0', 'MOUNTAIN CABLEWAY', 106975),
#  (840, '🚡', '1F6A1', 'AERIAL TRAMWAY', 104016),
#  (841, '🛂', '1F6C2', 'PASSPORT CONTROL', 103654),
#  (842, '🔠', '1F520', 'INPUT SYMBOL FOR LATIN CAPITAL LETTERS', 103234),
#  (843, '🔡', '1F521', 'INPUT SYMBOL FOR LATIN SMALL LETTERS', 101160),
#  (844, '🚱', '1F6B1', 'NON-POTABLE WATER SYMBOL', 92412),
#  (845, '🚟', '1F69F', 'SUSPENSION RAILWAY', 85790)]

# %% [markdown]
# ## Reflect database and Query

# %%
# Reflect Database into ORM class
Base = automap_base()
Base.prepare(engine, reflect=True)
Emoji = Base.classes.emoji

# %%
# Start a session to query the database
session = Session(engine)

# %% [markdown]
# Use Matplotlib to create a horizontal bar chart and plot the emoji `score` in descending order. Use `emoji_char` as the y-axis labels. Plot only the top 10 emojis ranked by score

# %%
# Query Emojis for `emoji_char`, `emoji_id`, and `score` and save the query into results
results = session.query(Emoji.emoji_char, Emoji.emoji_id, Emoji.score).\
    order_by(Emoji.score.desc()).all()

# %% [markdown]
# Unpack tuples using list comprehensions

# %%
# Unpack the `emoji_id` and `scores` from results and save into separate lists
emoji_id = [result[1] for result in results[:10]]
scores = [int(result[2]) for result in results[:10]]

# %%
print(scores[::-1])
print(emoji_id[::-1])
# Out:
# [377847645, 381679908, 441690175, 452489849, 484540701, 515991922, 652715459, 680382416, 840619939, 1814832150]
# ['1F618', '1F495', '1F612', '267B', '1F60A', '1F62D', '2665', '1F60D', '2764', '1F602']

# %%
print(scores[:])
print(emoji_id[:])
# Out:
# [1814832150, 840619939, 680382416, 652715459, 515991922, 484540701, 452489849, 441690175, 381679908, 377847645]
# ['1F602', '2764', '1F60D', '2665', '1F62D', '1F60A', '267B', '1F612', '1F495', '1F618']

# %% [markdown]
# ## Plot using Matplotlib

# %%
# fig, ax = plt.subplots()
# ypos = range(len(scores))
# ax.barh(ypos, scores[::-1])
# ax.set_yticks(ypos)
# plt.show()

# %%
# Create a horizontal bar chart and plot the `emoji_id` on the y-axis and the `score` on the x-axis
# Challenge: Try to plot the scores in descending order on the graph (The largest score is at the top)
fig, ax = plt.subplots()
ypos = range(1, len(scores)+1)
ax.barh(ypos, scores[::-1])
ax.set_xlabel("score")
ax.set_ylabel("emoji")
ax.set_yticks(ypos)
ax.set_yticklabels(emoji_id[::-1])
ax.set_title("Emoji Scores")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Plot using Pandas Plotting

# %% [markdown]
# Load the results into a Pandas DataFrame

# %%
# Load the results into a pandas dataframe. Set the index to the `emoji_id`
df = pd.DataFrame(results[:10], columns=['emoji_char', 'emoji_id', 'score'])
df.set_index('emoji_id', inplace=True, )
df
# Out:
#          emoji_char       score
# emoji_id
# 1F602             😂  1814832150
# 2764             ❤️   840619939
# 1F60D             😍   680382416
# 2665             ♥️   652715459
# 1F62D             😭   515991922
# 1F60A             😊   484540701
# 267B             ♻️   452489849
# 1F612             😒   441690175
# 1F495             💕   381679908
# 1F618             😘   377847645

# %% [markdown]
# Plot using Pandas

# %%
df.iloc[::-1]
# Out:
#          emoji_char       score
# emoji_id
# 1F618             😘   377847645
# 1F495             💕   381679908
# 1F612             😒   441690175
# 267B             ♻️   452489849
# 1F60A             😊   484540701
# 1F62D             😭   515991922
# 2665             ♥️   652715459
# 1F60D             😍   680382416
# 2764             ❤️   840619939
# 1F602             😂  1814832150

# %%
# Plot the dataframe as a horizontal bar chart using pandas plotting
df.iloc[::-1].plot.barh(title="emoji ranking")
plt.tight_layout()
plt.show()

# %%
# BONUS: Use Pandas `read_sql_query` to load a query statement directly into the DataFrame
stmt = session.query(Emoji).\
    order_by(Emoji.score.desc()).statement
df2 = pd.read_sql_query(stmt, session.bind)
df2.head(10)
# Out:
#    id emoji_char emoji_id                                 name       score
# 0   1          😂    1F602               FACE WITH TEARS OF JOY  1814832150
# 1   2         ❤️     2764                    HEAVY BLACK HEART   840619939
# 2   3          😍    1F60D  SMILING FACE WITH HEART-SHAPED EYES   680382416
# 3   4         ♥️     2665                     BLACK HEART SUIT   652715459
# 4   5          😭    1F62D                   LOUDLY CRYING FACE   515991922
# 5   6          😊    1F60A       SMILING FACE WITH SMILING EYES   484540701
# 6   7         ♻️     267B     BLACK UNIVERSAL RECYCLING SYMBOL   452489849
# 7   8          😒    1F612                        UNAMUSED FACE   441690175
# 8   9          💕    1F495                           TWO HEARTS   381679908
# 9  10          😘    1F618                 FACE THROWING A KISS   377847645

# %%
# Make a connection to the SQL database
conn = engine.connect()

# %%
stmt = session.query(Emoji).\
    order_by(Emoji.score.desc()).statement
df3 = pd.read_sql_query(stmt, conn)
df3.head(10)
# Out:
#    id emoji_char emoji_id                                 name       score
# 0   1          😂    1F602               FACE WITH TEARS OF JOY  1814832150
# 1   2         ❤️     2764                    HEAVY BLACK HEART   840619939
# 2   3          😍    1F60D  SMILING FACE WITH HEART-SHAPED EYES   680382416
# 3   4         ♥️     2665                     BLACK HEART SUIT   652715459
# 4   5          😭    1F62D                   LOUDLY CRYING FACE   515991922
# 5   6          😊    1F60A       SMILING FACE WITH SMILING EYES   484540701
# 6   7         ♻️     267B     BLACK UNIVERSAL RECYCLING SYMBOL   452489849
# 7   8          😒    1F612                        UNAMUSED FACE   441690175
# 8   9          💕    1F495                           TWO HEARTS   381679908
# 9  10          😘    1F618                 FACE THROWING A KISS   377847645
